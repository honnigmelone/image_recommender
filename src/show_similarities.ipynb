# %%
from similarities import calculate_similarities
from config import DATABASE_PATH
import sqlite3

# %%
conn = sqlite3.connect(DATABASE_PATH)
c = conn.cursor()

# %% [markdown]
# ### **DISCLAIMER**
#
# In this notebook you can use all the data you collected to get the k most similar images from an image in different modes and for different metrics

# %%
input_images = [r"C:\Users\niki\Downloads\boat.jpg"]

# %% [markdown]
# ### **EMBEDDINGS**

# %%
calculate_similarities(input_images, c, mode="embeddings", metric="cosine", top_k=5)

# %% [markdown]
# ### **COLOR RGB**

# %%
calculate_similarities(input_images, c, mode="rgb", metric="euclidean", top_k=5, verbose=True)
# Out:
# Time to load feature data: 0.0000 second
# Time to extract features: 0.5576 seconds
# Time to compute similarities: 0.7152 seconds
# Time to retrieve top-K images: 0.0000 seconds
# Total execution time: 1.2728 seconds

# %% [markdown]
# ### **A-HASHES**

# %%
calculate_similarities(input_images, c, mode="ahashes", metric="hamming", top_k=5)

# %% [markdown]
# ### **D-HASHES**

# %%
calculate_similarities(input_images, c, mode="dhashes", metric="hamming", top_k=5)

# %% [markdown]
# ### **Many input images**

# %%
input_images = [r"C:\Users\niki\Downloads\red.jpg",
                r"C:\Users\niki\Downloads\auto.jpg",
                r"C:\Users\niki\Downloads\landscape.jpg",
                r"C:\Users\niki\Downloads\space.jpg",
                r"C:\Users\niki\Downloads\johnpork.jpg"]

# %%
calculate_similarities(input_images, c, mode="rgb", metric="cosine", top_k=5)

# %%
conn.close()
